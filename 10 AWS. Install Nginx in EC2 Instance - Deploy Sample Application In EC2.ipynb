# %% [markdown]
# ## ✅ Objective:
# Install **Nginx** on EC2 Ubuntu instance and deploy a **custom HTML page**.
#
# ---
#
# ## 🔧 Commands Used:
#
# ### 1. **SSH into EC2:**
# ```bash
# ssh -i "mymachine.pem" ubuntu@<Public_IP>
# ```
#
# ---
#
# ### 2. **Switch to root user (optional but used):**
# ```bash
# sudo -i
# ```
#
# ---
#
# ### 3. **Install Nginx:**
# ```bash
# sudo apt-get install nginx -y
# ```
#
# > You saw a permission error earlier because you missed `sudo`. Fixed it by using `sudo -i`.
#
# ---
#
# ### 4. **Check Nginx Status:**
# ```bash
# service nginx status
# ```
#
# You confirmed it's **active (running)**.
#
# ---
#
# ### 5. **Check default Nginx HTML page:**
# ```bash
# curl localhost
# ```
#
# It showed the **default welcome page**, meaning Nginx is working fine.
#
# ---
#
# ### 6. **Go to Nginx root directory:**
# ```bash
# cd /var/www/html/
# ```
#
# ---
#
# ### 7. **Deploy your custom app (replace default page):**
# ```bash
# echo "Welcome to Mohit's instance" > index.html
# ```
#
# This command **overwrites** the `index.html` file with your own text.
#
# ---
#
# ### 8. **Verify your custom page:**
# ```bash
# curl localhost
# ```
#
# Output:
# ```
# Welcome to Mohit's instance
# ```
#
# ✅ Nginx is serving your custom content now.
#
# ---
#
# ## 🚀 Done!
# Your EC2 instance is running Nginx and serving your custom page.
