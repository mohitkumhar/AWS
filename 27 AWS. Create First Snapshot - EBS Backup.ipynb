# %% [markdown]
# ### Create First Snapshot – EBS Backup
#
# An **EBS Snapshot** is a way to back up your EBS volume safely. It captures the **entire state of your volume at a point in time** and stores it securely in Amazon S3 (managed by AWS).
#
# ---
#
# ### Why Create a Snapshot?
#
# - To **protect important data** from accidental loss.
# - To **restore** your EC2 volume quickly in case of failure.
# - To **clone or copy volumes** across regions or accounts.
#
# ---
#
# ### Step-by-Step: How to Create Your First Snapshot
#
# #### Step 1: Go to Volumes
# - Open AWS Console → **EC2 > Volumes**
# - Identify the volume you want to back up (e.g., `/dev/xvda`)
#
# #### Step 2: Create Snapshot
# - Select the volume → Click **Actions > Create Snapshot**
# - Enter a **Name** and optional **Description**
# - Click **Create Snapshot**
#
# > 📌 AWS will begin creating a point-in-time backup of the volume.
#
# ---
#
# ### Step 3: View Snapshot Status
# - Go to **EC2 > Snapshots**
# - You will see the new snapshot with status: `pending → completed`
#
# ---
#
# ### Step 4: Use the Snapshot
#
# You can use this snapshot to:
# - **Restore** a volume:
#   - Click on the snapshot → **Actions > Create Volume**
#   - Choose size, type, and AZ → Create
#   - Attach this volume to any EC2 instance
# - **Create AMI** (Image):
#   - Used to launch new EC2 instances
#
# ---
#
# ### Important Notes
#
# - Snapshots are **incremental**: after the first full snapshot, only changes are saved in future ones.
# - Stored internally in Amazon S3, **not visible directly** in S3.
# - You can **copy snapshots** to other regions for disaster recovery.
# - You can **encrypt** snapshots and share them with other AWS accounts.
#
# ---
#
# ### Summary Table
#
# | Task                      | Action                                              |
# |---------------------------|-----------------------------------------------------|
# | Start snapshot            | EC2 > Volumes > Actions > Create Snapshot           |
# | View snapshot status      | EC2 > Snapshots                                     |
# | Restore volume            | Actions > Create Volume                             |
# | Create AMI from snapshot  | Actions > Create Image                              |
# | Automate snapshots        | Use AWS Data Lifecycle Manager (DLM)                |
#
# ---
#
# ### Best Practices
#
# - Name snapshots with meaningful descriptions.
# - Schedule **regular snapshots** for production volumes.
# - Delete **unused snapshots** to save cost.
